# %% [markdown]
# #### Nesta etapa iremos criar toda estrutura necessária para nosso modelo de dados STAR schema.
#
# * Este deve ser um modelo que facilite a construção de dashboards para aquisição e a sua análise dos dados e será baseado em fator e dimensão.

# %%
import pandas as pd
import numpy as np
import os
import sys
from dotenv import load_dotenv

import warnings
warnings.filterwarnings('ignore')

# %%
# Importando as bibliotecas para o acesso ao Postgres.
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import psycopg2
from psycopg2 import OperationalError, errorcodes, errors, IntegrityError
import psycopg2.extras as extras

# %%
# Lendo os dados de um arquivo .csv
df_real = pd.read_csv(r'..\dados\aquisicao_clinicas_completo.csv',
                       parse_dates=['ACTIVITY_AT','CLINIC_CREATED_AT','TRIAL_START_DATE','TRIAL_END_DATE','SUBSCRIPTION_START_DATE','SUBSCRIPTION_END_DATE'])
df_real.head()
# Out:
#    CLINIC_ID             ACTIVITY_AT      ACTIVITY_TYPE             FEATURE  \
# 0       9825 2023-08-24 18:46:47.733  patient_discarded  patient_management
# 1       9984 2023-08-24 19:41:43.497    patient_created  patient_management
# 2       9984 2023-08-24 19:41:44.037  time_slot_created          scheduling
# 3       9984 2023-08-24 19:51:20.451    patient_created  patient_management
# 4       9984 2023-08-24 19:51:46.663  time_slot_created          scheduling
#
#      MODULE  IS_VALID_ACTIVITY       CLINIC_CREATED_AT  IS_CHAIN_CLINIC  \
# 0   patient               True 2023-08-21 09:14:34.763            False
# 1   patient              False 2023-08-24 19:40:58.432            False
# 2  schedule               True 2023-08-24 19:40:58.432            False
# 3   patient              False 2023-08-24 19:40:58.432            False
# 4  schedule               True 2023-08-24 19:40:58.432            False
#
#   FIRST_USER_HUBSPOT_SOURCE INTEREST_CATEGORY_SIGNUP  ...  \
# 0                   Inbound              Apenas BNPL  ...
# 1                   Inbound              BNPL e SaaS  ...
# 2                   Inbound              BNPL e SaaS  ...
# 3                   Inbound              BNPL e SaaS  ...
# 4                   Inbound              BNPL e SaaS  ...
#
#          STRIPE_SUBSCRIPTION_ID SUBSCRIPTION_START_DATE SUBSCRIPTION_END_DATE  \
# 0  sub_1Nj29VCpjOdJI4gTsWNO1Kzm              2023-08-25            2023-10-25
# 1                           NaN                     NaT                   NaT
# 2                           NaN                     NaT                   NaT
# 3                           NaN                     NaT                   NaT
# 4                           NaN                     NaT                   NaT
#
#   SUBSCRIPTION_PERIOD_DAYS  SUBSCRIPTION_PERIOD  SUBSCRIPTION_STATUS  \
# 0                     61.0   Entre 61 e 90 dias               active
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                      NaN                  NaN                  NaN
# 4                      NaN                  NaN                  NaN
#
#    BILLING_INTERVAL_IN_MONTHS  CLINICA_CONVERTIDA      FAIXA_NRO_ATIVIDADES  \
# 0                         1.0                True    Acima de 50 atividades
# 1                         NaN               False  Entre 11 e 20 atividades
# 2                         NaN               False  Entre 11 e 20 atividades
# 3                         NaN               False  Entre 11 e 20 atividades
# 4                         NaN               False  Entre 11 e 20 atividades
#
#   TRIAL_DURATION_INTERVAL
# 0              Até 7 dias
# 1              Até 7 dias
# 2              Até 7 dias
# 3              Até 7 dias
# 4              Até 7 dias
#
# [5 rows x 29 columns]

# %%
# Cria o dataset para a tabela clinica_dim
clinica_dim = df_real[['CLINIC_ID','CLINIC_CREATED_AT']].drop_duplicates(subset=['CLINIC_ID'])
clinica_dim
# Out:
#        CLINIC_ID       CLINIC_CREATED_AT
# 0           9825 2023-08-21 09:14:34.763
# 1           9984 2023-08-24 19:40:58.432
# 5           9986 2023-08-24 20:31:43.062
# 7           9988 2023-08-24 22:04:10.022
# 9           9690 2023-08-17 04:33:00.786
# ...          ...                     ...
# 12393       9011 2023-08-01 13:01:05.019
# 12395      11180 2023-09-27 14:01:04.040
# 12397      11146 2023-09-26 19:21:15.702
# 12399      10314 2023-09-05 01:05:51.799
# 12401      11031 2023-09-23 20:03:38.288
#
# [983 rows x 2 columns]

# %%
# Renomeando as colunas do dataframe para os mesmos nomes das colunas das tabelas no Postgres.
clinica_dim.rename(columns={'CLINIC_ID':'id_clinica',
                            'CLINIC_CREATED_AT':'data_cadastro'}, inplace=True)
clinica_dim
# Out:
#        id_clinica           data_cadastro
# 0            9825 2023-08-21 09:14:34.763
# 1            9984 2023-08-24 19:40:58.432
# 5            9986 2023-08-24 20:31:43.062
# 7            9988 2023-08-24 22:04:10.022
# 9            9690 2023-08-17 04:33:00.786
# ...           ...                     ...
# 12393        9011 2023-08-01 13:01:05.019
# 12395       11180 2023-09-27 14:01:04.040
# 12397       11146 2023-09-26 19:21:15.702
# 12399       10314 2023-09-05 01:05:51.799
# 12401       11031 2023-09-23 20:03:38.288
#
# [983 rows x 2 columns]

# %%
# Cria o dataset para a tabela funcionalidade_dim
funcionalidade_dim = df_real[['FEATURE']].drop_duplicates().reset_index()
funcionalidade_dim['index'] = funcionalidade_dim.index
funcionalidade_dim
# Out:
#     index              FEATURE
# 0       0   patient_management
# 1       1           scheduling
# 2       2       medical_record
# 3       3             anamnese
# 4       4      user_management
# 5       5    budget_management
# 6       6         credit_check
# 7       7                 bnpl
# 8       8  documents_and_files
# 9       9   revenue_management
# 10     10         payment_book

# %%
# Renomeando as colunas do dataframe para os mesmos nomes das colunas das tabelas no Postgres.
funcionalidade_dim.rename(columns={'index':'id_funcionalidade','FEATURE':'nom_funcionalidade'}, inplace=True)
funcionalidade_dim
# Out:
#     id_funcionalidade   nom_funcionalidade
# 0                   0   patient_management
# 1                   1           scheduling
# 2                   2       medical_record
# 3                   3             anamnese
# 4                   4      user_management
# 5                   5    budget_management
# 6                   6         credit_check
# 7                   7                 bnpl
# 8                   8  documents_and_files
# 9                   9   revenue_management
# 10                 10         payment_book

# %%
# Cria o dataset para a tabela canal_marketing_dim
canal_marketing_dim = df_real[['MARKETING_ATTRIBUITION_CHANNEL_GROUP']].drop_duplicates().reset_index(drop=True)
canal_marketing_dim['ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP'] = canal_marketing_dim.index
canal_marketing_dim
# Out:
#   MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                          Paid - meta
# 1                        Paid - google
# 2                                Other
# 3            Site ou Indicação Interna
# 4                              Organic
#
#    ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP
# 0                                        0
# 1                                        1
# 2                                        2
# 3                                        3
# 4                                        4

# %%
# Cria o dataset para a tabela trial_fato
trial_fato = df_real[['CLINIC_ID','TRIAL_START_DATE','TRIAL_END_DATE','TRIAL_DURATION','TRIAL_DURATION_INTERVAL', 'MARKETING_ATTRIBUITION_CHANNEL_GROUP'
         ,'HAS_ASKED_FOR_ACCREDITATION','IS_ACCREDITATION_APPROVED','CLINIC_ACCREDITATION_STATUS', 'FAIXA_NRO_ATIVIDADES', 'CLINICA_CONVERTIDA']].drop_duplicates(subset=['CLINIC_ID'])
trial_fato
# Out:
#        CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0           9825       2023-08-21     2023-08-25               4
# 1           9984       2023-08-24     2023-08-31               7
# 5           9986       2023-08-24     2023-09-14              21
# 7           9988       2023-08-24     2023-08-31               7
# 9           9690       2023-08-17     2023-08-24               7
# ...          ...              ...            ...             ...
# 12393       9011       2023-08-01     2023-10-11              71
# 12395      11180       2023-09-27     2023-10-10              13
# 12397      11146       2023-09-26     2023-10-17              21
# 12399      10314       2023-09-05     2023-10-17              42
# 12401      11031       2023-09-23     2023-10-18              25
#
#       TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                  Até 7 dias                          Paid - meta
# 1                  Até 7 dias                        Paid - google
# 5            Acima de 14 dias                        Paid - google
# 7                  Até 7 dias                        Paid - google
# 9                  Até 7 dias                                Other
# ...                       ...                                  ...
# 12393        Acima de 14 dias                          Paid - meta
# 12395       Entre 8 e 14 dias                          Paid - meta
# 12397        Acima de 14 dias                                Other
# 12399        Acima de 14 dias                          Paid - meta
# 12401        Acima de 14 dias                          Paid - meta
#
#        HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                             True                       True
# 1                             True                       True
# 5                             True                       True
# 7                            False                      False
# 9                            False                      False
# ...                            ...                        ...
# 12393                         True                       True
# 12395                         True                       True
# 12397                         True                       True
# 12399                         True                       True
# 12401                         True                      False
#
#       CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  \
# 0                       Concluído    Acima de 50 atividades
# 1                       Concluído  Entre 11 e 20 atividades
# 5                       Concluído         Até 10 atividades
# 7             Não aderiu ao plano         Até 10 atividades
# 9             Não aderiu ao plano         Até 10 atividades
# ...                           ...                       ...
# 12393                   Concluído                       NaN
# 12395                   Concluído                       NaN
# 12397                   Concluído                       NaN
# 12399                   Concluído         Até 10 atividades
# 12401                   Reprovado         Até 10 atividades
#
#        CLINICA_CONVERTIDA
# 0                    True
# 1                   False
# 5                   False
# 7                   False
# 9                   False
# ...                   ...
# 12393               False
# 12395                True
# 12397               False
# 12399                True
# 12401                True
#
# [983 rows x 11 columns]

# %%
# Funcionalidade mais utilizada pela clinica durante o trial.
df_real[['CLINIC_ID','FEATURE']].loc[df_real['IS_VALID_ACTIVITY']].groupby(by=['CLINIC_ID'])['FEATURE'].value_counts().reset_index().drop_duplicates('CLINIC_ID')
# Out:
#       CLINIC_ID             FEATURE  count
# 0          8994      medical_record      2
# 4          8998      medical_record     11
# 9          9000      medical_record     13
# 18         9004            anamnese      1
# 19         9014      medical_record      1
# ...         ...                 ...    ...
# 2291      11294          scheduling      4
# 2294      11295  patient_management      2
# 2296      11296          scheduling      1
# 2297      11301          scheduling      1
# 2298      11302          scheduling      1
#
# [856 rows x 3 columns]

# %%
# Funcionalidade mais utilizada pela clinica durante o trial.
funcionalidade_mais_utilizada = df_real[['CLINIC_ID','FEATURE']].loc[df_real['IS_VALID_ACTIVITY']].groupby(by=['CLINIC_ID','FEATURE'],
                                                                            as_index=False).value_counts().sort_values(by=['CLINIC_ID','count']).drop_duplicates('CLINIC_ID', keep='last' )
funcionalidade_mais_utilizada
# Out:
#       CLINIC_ID             FEATURE  count
# 1          8994      medical_record      2
# 6          8998      medical_record     11
# 13         9000      medical_record     13
# 18         9004            anamnese      1
# 20         9014     user_management      1
# ...         ...                 ...    ...
# 2293      11294          scheduling      4
# 2294      11295  patient_management      2
# 2296      11296          scheduling      1
# 2297      11301          scheduling      1
# 2298      11302          scheduling      1
#
# [856 rows x 3 columns]

# %%
# Funcionalidades e numero de vezes utilizada pela clinica durante o trial.
funcionalidade_utilizada_fato = df_real[['CLINIC_ID','FEATURE']].loc[df_real['IS_VALID_ACTIVITY']].groupby(by=['CLINIC_ID','FEATURE'],as_index=False).value_counts()
funcionalidade_utilizada_fato
# Out:
#       CLINIC_ID             FEATURE  count
# 0          8994   budget_management      1
# 1          8994      medical_record      2
# 2          8994  revenue_management      1
# 3          8994          scheduling      1
# 4          8998            anamnese      2
# ...         ...                 ...    ...
# 2294      11295  patient_management      2
# 2295      11295          scheduling      1
# 2296      11296          scheduling      1
# 2297      11301          scheduling      1
# 2298      11302          scheduling      1
#
# [2299 rows x 3 columns]

# %%
# Agrega as informações da PK das funcionalidades.
funcionalidade_utilizada_fato = pd.merge(funcionalidade_utilizada_fato, funcionalidade_dim, left_on='FEATURE', right_on='nom_funcionalidade', how='left')
funcionalidade_utilizada_fato
# Out:
#       CLINIC_ID             FEATURE  count  id_funcionalidade  \
# 0          8994   budget_management      1                  5
# 1          8994      medical_record      2                  2
# 2          8994  revenue_management      1                  9
# 3          8994          scheduling      1                  1
# 4          8998            anamnese      2                  3
# ...         ...                 ...    ...                ...
# 2294      11295  patient_management      2                  0
# 2295      11295          scheduling      1                  1
# 2296      11296          scheduling      1                  1
# 2297      11301          scheduling      1                  1
# 2298      11302          scheduling      1                  1
#
#       nom_funcionalidade
# 0      budget_management
# 1         medical_record
# 2     revenue_management
# 3             scheduling
# 4               anamnese
# ...                  ...
# 2294  patient_management
# 2295          scheduling
# 2296          scheduling
# 2297          scheduling
# 2298          scheduling
#
# [2299 rows x 5 columns]

# %%
# Ajustes para exportar para a tabela no Postgres.
# Excluindo colunas
funcionalidade_utilizada_fato.drop(columns=['FEATURE'], inplace=True)
# Renomeando colunas
funcionalidade_utilizada_fato.rename(columns={'CLINIC_ID':'id_clinica', 'count':'num_qtde_vezes'}, inplace=True)
# Ajustando as posições
funcionalidade_utilizada_fato = funcionalidade_utilizada_fato[['id_clinica','id_funcionalidade', 'num_qtde_vezes']]
funcionalidade_utilizada_fato
# Out:
#       id_clinica  id_funcionalidade  num_qtde_vezes
# 0           8994                  5               1
# 1           8994                  2               2
# 2           8994                  9               1
# 3           8994                  1               1
# 4           8998                  3               2
# ...          ...                ...             ...
# 2294       11295                  0               2
# 2295       11295                  1               1
# 2296       11296                  1               1
# 2297       11301                  1               1
# 2298       11302                  1               1
#
# [2299 rows x 3 columns]

# %%
# Total de atividades válidas por clínica durante o Trial.
total_atividades_validas_por_clinica = df_real.loc[df_real['IS_VALID_ACTIVITY']].groupby(by='CLINIC_ID', as_index=False)['ACTIVITY_TYPE'].count().rename(columns={'ACTIVITY_TYPE':'TOTAL_ATIVIDADES_VALIDAS'})
total_atividades_validas_por_clinica
# Out:
#      CLINIC_ID  TOTAL_ATIVIDADES_VALIDAS
# 0         8994                         5
# 1         8998                        24
# 2         9000                        34
# 3         9004                         1
# 4         9014                         2
# ..         ...                       ...
# 851      11294                         7
# 852      11295                         3
# 853      11296                         1
# 854      11301                         1
# 855      11302                         1
#
# [856 rows x 2 columns]

# %%
# Agrega as informações do Total de atividades válidas por clínica durante o Trial.
trial_fato = pd.merge(trial_fato, total_atividades_validas_por_clinica, on='CLINIC_ID', how='left')
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído                       NaN               False
# 979                   Concluído                       NaN                True
# 980                   Concluído                       NaN               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS
# 0                       173.0
# 1                        14.0
# 2                         4.0
# 3                         1.0
# 4                         1.0
# ..                        ...
# 978                       NaN
# 979                       NaN
# 980                       NaN
# 981                       1.0
# 982                       7.0
#
# [983 rows x 12 columns]

# %%
# Substituindo os valores nulo por 0.
trial_fato['TOTAL_ATIVIDADES_VALIDAS'].fillna(0, inplace=True)
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído                       NaN               False
# 979                   Concluído                       NaN                True
# 980                   Concluído                       NaN               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS
# 0                       173.0
# 1                        14.0
# 2                         4.0
# 3                         1.0
# 4                         1.0
# ..                        ...
# 978                       0.0
# 979                       0.0
# 980                       0.0
# 981                       1.0
# 982                       7.0
#
# [983 rows x 12 columns]

# %%
trial_fato.loc[trial_fato['TOTAL_ATIVIDADES_VALIDAS'].isna()]
# Out:
# Empty DataFrame
# Columns: [CLINIC_ID, TRIAL_START_DATE, TRIAL_END_DATE, TRIAL_DURATION, TRIAL_DURATION_INTERVAL, MARKETING_ATTRIBUITION_CHANNEL_GROUP, HAS_ASKED_FOR_ACCREDITATION, IS_ACCREDITATION_APPROVED, CLINIC_ACCREDITATION_STATUS, FAIXA_NRO_ATIVIDADES, CLINICA_CONVERTIDA, TOTAL_ATIVIDADES_VALIDAS]
# Index: []

# %%
# Converte a TOTAL_ATIVIDADES_VALIDAS para o tipo Int64.
trial_fato['TOTAL_ATIVIDADES_VALIDAS'] = trial_fato['TOTAL_ATIVIDADES_VALIDAS'].astype('Int64')
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído                       NaN               False
# 979                   Concluído                       NaN                True
# 980                   Concluído                       NaN               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS
# 0                         173
# 1                          14
# 2                           4
# 3                           1
# 4                           1
# ..                        ...
# 978                         0
# 979                         0
# 980                         0
# 981                         1
# 982                         7
#
# [983 rows x 12 columns]

# %%
trial_fato.loc[trial_fato['TOTAL_ATIVIDADES_VALIDAS'] == 0]
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 10        9933       2023-08-23     2023-08-30               7
# 12        9888       2023-08-22     2023-08-29               7
# 19        9940       2023-08-23     2023-08-30               7
# 22        9758       2023-08-18     2023-08-25               7
# 32        9948       2023-08-23     2023-08-30               7
# ..         ...              ...            ...             ...
# 974      11291       2023-09-30     2023-10-07               7
# 975      11190       2023-09-27     2023-10-04               7
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 10               Até 7 dias                        Paid - google
# 12               Até 7 dias                        Paid - google
# 19               Até 7 dias                              Organic
# 22               Até 7 dias                                Other
# 32               Até 7 dias                          Paid - meta
# ..                      ...                                  ...
# 974              Até 7 dias                          Paid - meta
# 975              Até 7 dias                                Other
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 10                          True                       True
# 12                          True                       True
# 19                          True                       True
# 22                          True                       True
# 32                          True                       True
# ..                           ...                        ...
# 974                         True                       True
# 975                         True                       True
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
#
#     CLINIC_ACCREDITATION_STATUS FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 10                    Concluído                  NaN                True
# 12                    Concluído                  NaN               False
# 19                    Concluído                  NaN                True
# 22                    Concluído                  NaN               False
# 32                    Concluído                  NaN                True
# ..                          ...                  ...                 ...
# 974                   Concluído                  NaN               False
# 975                   Concluído                  NaN                True
# 978                   Concluído                  NaN               False
# 979                   Concluído                  NaN                True
# 980                   Concluído                  NaN               False
#
#      TOTAL_ATIVIDADES_VALIDAS
# 10                          0
# 12                          0
# 19                          0
# 22                          0
# 32                          0
# ..                        ...
# 974                         0
# 975                         0
# 978                         0
# 979                         0
# 980                         0
#
# [127 rows x 12 columns]

# %%
# Substituindo os valores nulo por 'Não realizou atividades'.
trial_fato['FAIXA_NRO_ATIVIDADES'].fillna('Não realizou atividades', inplace=True)
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído   Não realizou atividades               False
# 979                   Concluído   Não realizou atividades                True
# 980                   Concluído   Não realizou atividades               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS
# 0                         173
# 1                          14
# 2                           4
# 3                           1
# 4                           1
# ..                        ...
# 978                         0
# 979                         0
# 980                         0
# 981                         1
# 982                         7
#
# [983 rows x 12 columns]

# %%
# Agrega as informações da PK dos canais de marketing.
trial_fato = pd.merge(trial_fato, canal_marketing_dim, on='MARKETING_ATTRIBUITION_CHANNEL_GROUP', how='left')
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído   Não realizou atividades               False
# 979                   Concluído   Não realizou atividades                True
# 980                   Concluído   Não realizou atividades               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS  ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP
# 0                         173                                        0
# 1                          14                                        1
# 2                           4                                        1
# 3                           1                                        1
# 4                           1                                        2
# ..                        ...                                      ...
# 978                         0                                        0
# 979                         0                                        0
# 980                         0                                        2
# 981                         1                                        0
# 982                         7                                        0
#
# [983 rows x 13 columns]

# %%
# Clinicas convertidas 
# A conversão requer um registro de assinatura onde STRIPE_SUBSCRIPTION_ID seja diferente de NaN, não importando o status.
clinicas_convertidas = df_real.loc[~df_real['STRIPE_SUBSCRIPTION_ID'].isna()].drop_duplicates(subset=['CLINIC_ID'])['CLINIC_ID']
clinicas_convertidas
# Out:
# 0         9825
# 11        9989
# 13        9990
# 17        9993
# 59        9933
#          ...
# 12249    11190
# 12331    11242
# 12395    11180
# 12399    10314
# 12401    11031
# Name: CLINIC_ID, Length: 270, dtype: int64

# %%
# Clinica foi convertida? Fez a assinatura ou não.
# trial_fato['REALIZOU_ASSINATURA'] =  np.where(trial_fato['CLINIC_ID'].isin(clinicas_convertidas), True, False)
# trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     MARKETING_ATTRIBUITION_CHANNEL_GROUP  HAS_ASKED_FOR_ACCREDITATION  \
# 0                            Paid - meta                         True
# 1                          Paid - google                         True
# 2                          Paid - google                         True
# 3                          Paid - google                        False
# 4                                  Other                        False
# ..                                   ...                          ...
# 978                          Paid - meta                         True
# 979                          Paid - meta                         True
# 980                                Other                         True
# 981                          Paid - meta                         True
# 982                          Paid - meta                         True
#
#      IS_ACCREDITATION_APPROVED CLINIC_ACCREDITATION_STATUS  \
# 0                         True                   Concluído
# 1                         True                   Concluído
# 2                         True                   Concluído
# 3                        False         Não aderiu ao plano
# 4                        False         Não aderiu ao plano
# ..                         ...                         ...
# 978                       True                   Concluído
# 979                       True                   Concluído
# 980                       True                   Concluído
# 981                       True                   Concluído
# 982                      False                   Reprovado
#
#      TOTAL_ATIVIDADES_VALIDAS_x  TOTAL_ATIVIDADES_VALIDAS_y  \
# 0                         173.0                       173.0
# 1                          14.0                        14.0
# 2                           4.0                         4.0
# 3                           1.0                         1.0
# 4                           1.0                         1.0
# ..                          ...                         ...
# 978                         NaN                         NaN
# 979                         NaN                         NaN
# 980                         NaN                         NaN
# 981                         1.0                         1.0
# 982                         7.0                         7.0
#
#      TOTAL_ATIVIDADES_VALIDAS  ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                         173                                        0
# 1                          14                                        1
# 2                           4                                        1
# 3                           1                                        1
# 4                           1                                        2
# ..                        ...                                      ...
# 978                         0                                        0
# 979                         0                                        0
# 980                         0                                        2
# 981                         1                                        0
# 982                         7                                        0
#
#      REALIZOU_ASSINATURA
# 0                   True
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 978                False
# 979                 True
# 980                False
# 981                 True
# 982                 True
#
# [983 rows x 13 columns]

# %%
# Data da conversão da clinica.
conversao_clinica = df_real.loc[~df_real['STRIPE_SUBSCRIPTION_ID'].isna()].drop_duplicates(subset=['CLINIC_ID'])[['CLINIC_ID','TRIAL_START_DATE','STRIPE_SUBSCRIPTION_ID','SUBSCRIPTION_START_DATE', 'SUBSCRIPTION_STATUS']]
conversao_clinica
# Out:
#        CLINIC_ID TRIAL_START_DATE        STRIPE_SUBSCRIPTION_ID  \
# 0           9825       2023-08-21  sub_1Nj29VCpjOdJI4gTsWNO1Kzm
# 11          9989       2023-08-24  sub_1NnMOZCpjOdJI4gTS2Z7QaGE
# 13          9990       2023-08-24  sub_1Niq9NCpjOdJI4gTlcWX7Jfj
# 17          9993       2023-08-25  sub_1NzOWSCpjOdJI4gTtwNWDOPP
# 59          9933       2023-08-23  sub_1Nkq5JCpjOdJI4gTFQQbh2Oh
# ...          ...              ...                           ...
# 12249      11190       2023-09-27  sub_1NxcoXCpjOdJI4gTt4JA8e3g
# 12331      11242       2023-09-28  sub_1O3028CpjOdJI4gTGwA9zyu5
# 12395      11180       2023-09-27  sub_1NzmetCpjOdJI4gTROeKTccm
# 12399      10314       2023-09-05  sub_1O2F0FCpjOdJI4gT1kqeULiV
# 12401      11031       2023-09-23  sub_1O2gIxCpjOdJI4gTm01tQrxp
#
#       SUBSCRIPTION_START_DATE SUBSCRIPTION_STATUS
# 0                  2023-08-25              active
# 11                 2023-09-06              active
# 13                 2023-08-24              active
# 17                 2023-10-09              active
# 59                 2023-08-30              active
# ...                       ...                 ...
# 12249              2023-10-04              active
# 12331              2023-10-19              active
# 12395              2023-10-10              active
# 12399              2023-10-17              active
# 12401              2023-10-18            canceled
#
# [270 rows x 5 columns]

# %%
# Tempo decorrido em dias desde o início do trial até a conversão para assinatura paga.
conversao_clinica['NUM_DIAS_PARA_ASSINATURA'] = (conversao_clinica['SUBSCRIPTION_START_DATE'] - conversao_clinica['TRIAL_START_DATE']).dt.days
conversao_clinica
# Out:
#        CLINIC_ID TRIAL_START_DATE        STRIPE_SUBSCRIPTION_ID  \
# 0           9825       2023-08-21  sub_1Nj29VCpjOdJI4gTsWNO1Kzm
# 11          9989       2023-08-24  sub_1NnMOZCpjOdJI4gTS2Z7QaGE
# 13          9990       2023-08-24  sub_1Niq9NCpjOdJI4gTlcWX7Jfj
# 17          9993       2023-08-25  sub_1NzOWSCpjOdJI4gTtwNWDOPP
# 59          9933       2023-08-23  sub_1Nkq5JCpjOdJI4gTFQQbh2Oh
# ...          ...              ...                           ...
# 12249      11190       2023-09-27  sub_1NxcoXCpjOdJI4gTt4JA8e3g
# 12331      11242       2023-09-28  sub_1O3028CpjOdJI4gTGwA9zyu5
# 12395      11180       2023-09-27  sub_1NzmetCpjOdJI4gTROeKTccm
# 12399      10314       2023-09-05  sub_1O2F0FCpjOdJI4gT1kqeULiV
# 12401      11031       2023-09-23  sub_1O2gIxCpjOdJI4gTm01tQrxp
#
#       SUBSCRIPTION_START_DATE SUBSCRIPTION_STATUS  NUM_DIAS_PARA_ASSINATURA
# 0                  2023-08-25              active                         4
# 11                 2023-09-06              active                        13
# 13                 2023-08-24              active                         0
# 17                 2023-10-09              active                        45
# 59                 2023-08-30              active                         7
# ...                       ...                 ...                       ...
# 12249              2023-10-04              active                         7
# 12331              2023-10-19              active                        21
# 12395              2023-10-10              active                        13
# 12399              2023-10-17              active                        42
# 12401              2023-10-18            canceled                        25
#
# [270 rows x 6 columns]

# %%
conversao_clinica['NUM_DIAS_PARA_ASSINATURA'].mean()
# Out:
# 9.311111111111112

# %%
# Agrega as informações da conversão da clínica.
trial_fato = pd.merge(trial_fato, conversao_clinica, on='CLINIC_ID', how='left')
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE_x TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825         2023-08-21     2023-08-25               4
# 1         9984         2023-08-24     2023-08-31               7
# 2         9986         2023-08-24     2023-09-14              21
# 3         9988         2023-08-24     2023-08-31               7
# 4         9690         2023-08-17     2023-08-24               7
# ..         ...                ...            ...             ...
# 978       9011         2023-08-01     2023-10-11              71
# 979      11180         2023-09-27     2023-10-10              13
# 980      11146         2023-09-26     2023-10-17              21
# 981      10314         2023-09-05     2023-10-17              42
# 982      11031         2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído   Não realizou atividades               False
# 979                   Concluído   Não realizou atividades                True
# 980                   Concluído   Não realizou atividades               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS  ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                         173                                        0
# 1                          14                                        1
# 2                           4                                        1
# 3                           1                                        1
# 4                           1                                        2
# ..                        ...                                      ...
# 978                         0                                        0
# 979                         0                                        0
# 980                         0                                        2
# 981                         1                                        0
# 982                         7                                        0
#
#     TRIAL_START_DATE_y        STRIPE_SUBSCRIPTION_ID SUBSCRIPTION_START_DATE  \
# 0           2023-08-21  sub_1Nj29VCpjOdJI4gTsWNO1Kzm              2023-08-25
# 1                  NaT                           NaN                     NaT
# 2                  NaT                           NaN                     NaT
# 3                  NaT                           NaN                     NaT
# 4                  NaT                           NaN                     NaT
# ..                 ...                           ...                     ...
# 978                NaT                           NaN                     NaT
# 979         2023-09-27  sub_1NzmetCpjOdJI4gTROeKTccm              2023-10-10
# 980                NaT                           NaN                     NaT
# 981         2023-09-05  sub_1O2F0FCpjOdJI4gT1kqeULiV              2023-10-17
# 982         2023-09-23  sub_1O2gIxCpjOdJI4gTm01tQrxp              2023-10-18
#
#     SUBSCRIPTION_STATUS  NUM_DIAS_PARA_ASSINATURA
# 0                active                       4.0
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
# ..                  ...                       ...
# 978                 NaN                       NaN
# 979              active                      13.0
# 980                 NaN                       NaN
# 981              active                      42.0
# 982            canceled                      25.0
#
# [983 rows x 18 columns]

# %%
# Converte a NUM_DIAS_PARA_ASSINATURA para o tipo Int64.
trial_fato['NUM_DIAS_PARA_ASSINATURA'] = trial_fato['NUM_DIAS_PARA_ASSINATURA'].astype('Int64')
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE_x TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825         2023-08-21     2023-08-25               4
# 1         9984         2023-08-24     2023-08-31               7
# 2         9986         2023-08-24     2023-09-14              21
# 3         9988         2023-08-24     2023-08-31               7
# 4         9690         2023-08-17     2023-08-24               7
# ..         ...                ...            ...             ...
# 978       9011         2023-08-01     2023-10-11              71
# 979      11180         2023-09-27     2023-10-10              13
# 980      11146         2023-09-26     2023-10-17              21
# 981      10314         2023-09-05     2023-10-17              42
# 982      11031         2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído   Não realizou atividades               False
# 979                   Concluído   Não realizou atividades                True
# 980                   Concluído   Não realizou atividades               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS  ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                         173                                        0
# 1                          14                                        1
# 2                           4                                        1
# 3                           1                                        1
# 4                           1                                        2
# ..                        ...                                      ...
# 978                         0                                        0
# 979                         0                                        0
# 980                         0                                        2
# 981                         1                                        0
# 982                         7                                        0
#
#     TRIAL_START_DATE_y        STRIPE_SUBSCRIPTION_ID SUBSCRIPTION_START_DATE  \
# 0           2023-08-21  sub_1Nj29VCpjOdJI4gTsWNO1Kzm              2023-08-25
# 1                  NaT                           NaN                     NaT
# 2                  NaT                           NaN                     NaT
# 3                  NaT                           NaN                     NaT
# 4                  NaT                           NaN                     NaT
# ..                 ...                           ...                     ...
# 978                NaT                           NaN                     NaT
# 979         2023-09-27  sub_1NzmetCpjOdJI4gTROeKTccm              2023-10-10
# 980                NaT                           NaN                     NaT
# 981         2023-09-05  sub_1O2F0FCpjOdJI4gT1kqeULiV              2023-10-17
# 982         2023-09-23  sub_1O2gIxCpjOdJI4gTm01tQrxp              2023-10-18
#
#     SUBSCRIPTION_STATUS  NUM_DIAS_PARA_ASSINATURA
# 0                active                         4
# 1                   NaN                      <NA>
# 2                   NaN                      <NA>
# 3                   NaN                      <NA>
# 4                   NaN                      <NA>
# ..                  ...                       ...
# 978                 NaN                      <NA>
# 979              active                        13
# 980                 NaN                      <NA>
# 981              active                        42
# 982            canceled                        25
#
# [983 rows x 18 columns]

# %%
# Renomeia a coluna TRIAL_START_DATE_x	para TRIAL_START_DATE
trial_fato.rename(columns={'TRIAL_START_DATE_x': 'TRIAL_START_DATE'}, inplace=True)
# Exclui a coluna TRIAL_START_DATE_y
trial_fato.drop(columns=['TRIAL_START_DATE_y'], inplace=True)
trial_fato
# Out:
#      CLINIC_ID TRIAL_START_DATE TRIAL_END_DATE  TRIAL_DURATION  \
# 0         9825       2023-08-21     2023-08-25               4
# 1         9984       2023-08-24     2023-08-31               7
# 2         9986       2023-08-24     2023-09-14              21
# 3         9988       2023-08-24     2023-08-31               7
# 4         9690       2023-08-17     2023-08-24               7
# ..         ...              ...            ...             ...
# 978       9011       2023-08-01     2023-10-11              71
# 979      11180       2023-09-27     2023-10-10              13
# 980      11146       2023-09-26     2023-10-17              21
# 981      10314       2023-09-05     2023-10-17              42
# 982      11031       2023-09-23     2023-10-18              25
#
#     TRIAL_DURATION_INTERVAL MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                Até 7 dias                          Paid - meta
# 1                Até 7 dias                        Paid - google
# 2          Acima de 14 dias                        Paid - google
# 3                Até 7 dias                        Paid - google
# 4                Até 7 dias                                Other
# ..                      ...                                  ...
# 978        Acima de 14 dias                          Paid - meta
# 979       Entre 8 e 14 dias                          Paid - meta
# 980        Acima de 14 dias                                Other
# 981        Acima de 14 dias                          Paid - meta
# 982        Acima de 14 dias                          Paid - meta
#
#      HAS_ASKED_FOR_ACCREDITATION  IS_ACCREDITATION_APPROVED  \
# 0                           True                       True
# 1                           True                       True
# 2                           True                       True
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 978                         True                       True
# 979                         True                       True
# 980                         True                       True
# 981                         True                       True
# 982                         True                      False
#
#     CLINIC_ACCREDITATION_STATUS      FAIXA_NRO_ATIVIDADES  CLINICA_CONVERTIDA  \
# 0                     Concluído    Acima de 50 atividades                True
# 1                     Concluído  Entre 11 e 20 atividades               False
# 2                     Concluído         Até 10 atividades               False
# 3           Não aderiu ao plano         Até 10 atividades               False
# 4           Não aderiu ao plano         Até 10 atividades               False
# ..                          ...                       ...                 ...
# 978                   Concluído   Não realizou atividades               False
# 979                   Concluído   Não realizou atividades                True
# 980                   Concluído   Não realizou atividades               False
# 981                   Concluído         Até 10 atividades                True
# 982                   Reprovado         Até 10 atividades                True
#
#      TOTAL_ATIVIDADES_VALIDAS  ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                         173                                        0
# 1                          14                                        1
# 2                           4                                        1
# 3                           1                                        1
# 4                           1                                        2
# ..                        ...                                      ...
# 978                         0                                        0
# 979                         0                                        0
# 980                         0                                        2
# 981                         1                                        0
# 982                         7                                        0
#
#            STRIPE_SUBSCRIPTION_ID SUBSCRIPTION_START_DATE SUBSCRIPTION_STATUS  \
# 0    sub_1Nj29VCpjOdJI4gTsWNO1Kzm              2023-08-25              active
# 1                             NaN                     NaT                 NaN
# 2                             NaN                     NaT                 NaN
# 3                             NaN                     NaT                 NaN
# 4                             NaN                     NaT                 NaN
# ..                            ...                     ...                 ...
# 978                           NaN                     NaT                 NaN
# 979  sub_1NzmetCpjOdJI4gTROeKTccm              2023-10-10              active
# 980                           NaN                     NaT                 NaN
# 981  sub_1O2F0FCpjOdJI4gT1kqeULiV              2023-10-17              active
# 982  sub_1O2gIxCpjOdJI4gTm01tQrxp              2023-10-18            canceled
#
#      NUM_DIAS_PARA_ASSINATURA
# 0                           4
# 1                        <NA>
# 2                        <NA>
# 3                        <NA>
# 4                        <NA>
# ..                        ...
# 978                      <NA>
# 979                        13
# 980                      <NA>
# 981                        42
# 982                        25
#
# [983 rows x 17 columns]

# %%
# Ajustes para exportar para a tabela no Postgres.
# Renomenando as colunas
trial_fato.rename(columns={'CLINIC_ID':'id_clinica', 'ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP': 'id_canal', 'TRIAL_START_DATE':'data_inicio_trial',
                           'TRIAL_END_DATE':'data_fim_trial', 'TRIAL_DURATION':'num_dias_trial', 'TOTAL_ATIVIDADES_VALIDAS': 'total_atividades_realizadas',
                           'HAS_ASKED_FOR_ACCREDITATION':'solicitou_credenciamento', 'IS_ACCREDITATION_APPROVED':'credenciamento_aprovado',
                            'CLINIC_ACCREDITATION_STATUS':'credenciamento_status',
                           'CLINICA_CONVERTIDA':'conversao', 'SUBSCRIPTION_START_DATE': 'data_assinatura', 'SUBSCRIPTION_STATUS':'status_assinatura',
                             'NUM_DIAS_PARA_ASSINATURA': 'num_dias_para_assinatura', 'TRIAL_DURATION_INTERVAL':'intervalo_duracao_trial', 
                             'FAIXA_NRO_ATIVIDADES':'intervalo_nro_atividades'},
                           inplace=True)
trial_fato = trial_fato[['id_clinica','id_canal','data_inicio_trial','data_fim_trial','num_dias_trial', 'intervalo_duracao_trial',
                         'total_atividades_realizadas','intervalo_nro_atividades', 
                         'solicitou_credenciamento','credenciamento_aprovado','credenciamento_status',
                         'conversao','data_assinatura','status_assinatura','num_dias_para_assinatura']]
trial_fato
# Out:
#      id_clinica  id_canal data_inicio_trial data_fim_trial  num_dias_trial  \
# 0          9825         0        2023-08-21     2023-08-25               4
# 1          9984         1        2023-08-24     2023-08-31               7
# 2          9986         1        2023-08-24     2023-09-14              21
# 3          9988         1        2023-08-24     2023-08-31               7
# 4          9690         2        2023-08-17     2023-08-24               7
# ..          ...       ...               ...            ...             ...
# 978        9011         0        2023-08-01     2023-10-11              71
# 979       11180         0        2023-09-27     2023-10-10              13
# 980       11146         2        2023-09-26     2023-10-17              21
# 981       10314         0        2023-09-05     2023-10-17              42
# 982       11031         0        2023-09-23     2023-10-18              25
#
#     intervalo_duracao_trial  total_atividades_realizadas  \
# 0                Até 7 dias                          173
# 1                Até 7 dias                           14
# 2          Acima de 14 dias                            4
# 3                Até 7 dias                            1
# 4                Até 7 dias                            1
# ..                      ...                          ...
# 978        Acima de 14 dias                            0
# 979       Entre 8 e 14 dias                            0
# 980        Acima de 14 dias                            0
# 981        Acima de 14 dias                            1
# 982        Acima de 14 dias                            7
#
#      intervalo_nro_atividades  solicitou_credenciamento  \
# 0      Acima de 50 atividades                      True
# 1    Entre 11 e 20 atividades                      True
# 2           Até 10 atividades                      True
# 3           Até 10 atividades                     False
# 4           Até 10 atividades                     False
# ..                        ...                       ...
# 978   Não realizou atividades                      True
# 979   Não realizou atividades                      True
# 980   Não realizou atividades                      True
# 981         Até 10 atividades                      True
# 982         Até 10 atividades                      True
#
#      credenciamento_aprovado credenciamento_status  conversao data_assinatura  \
# 0                       True             Concluído       True      2023-08-25
# 1                       True             Concluído      False             NaT
# 2                       True             Concluído      False             NaT
# 3                      False   Não aderiu ao plano      False             NaT
# 4                      False   Não aderiu ao plano      False             NaT
# ..                       ...                   ...        ...             ...
# 978                     True             Concluído      False             NaT
# 979                     True             Concluído       True      2023-10-10
# 980                     True             Concluído      False             NaT
# 981                     True             Concluído       True      2023-10-17
# 982                    False             Reprovado       True      2023-10-18
#
#     status_assinatura  num_dias_para_assinatura
# 0              active                         4
# 1                 NaN                      <NA>
# 2                 NaN                      <NA>
# 3                 NaN                      <NA>
# 4                 NaN                      <NA>
# ..                ...                       ...
# 978               NaN                      <NA>
# 979            active                        13
# 980               NaN                      <NA>
# 981            active                        42
# 982          canceled                        25
#
# [983 rows x 15 columns]

# %%
trial_fato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_clinica                   983 non-null    int64
#  1   id_canal                     983 non-null    int64
#  2   data_inicio_trial            983 non-null    datetime64[ns]
#  3   data_fim_trial               983 non-null    datetime64[ns]
#  4   num_dias_trial               983 non-null    int64
#  5   intervalo_duracao_trial      983 non-null    object
#  6   total_atividades_realizadas  983 non-null    Int64
#  7   intervalo_nro_atividades     983 non-null    object
#  8   solicitou_credenciamento     983 non-null    bool
#  9   credenciamento_aprovado      983 non-null    bool
#  10  credenciamento_status        983 non-null    object
#  11  conversao                    983 non-null    bool
#  12  data_assinatura              270 non-null    datetime64[ns]
#  13  status_assinatura            270 non-null    object
#  14  num_dias_para_assinatura     270 non-null    Int64
# dtypes: Int64(2), bool(3), datetime64[ns](3), int64(3), object(4)
# memory usage: 97.1+ KB

# %%
# Alterar o tipo de dado das colunas boolean para str.
trial_fato['solicitou_credenciamento'] = trial_fato['solicitou_credenciamento'].astype('str')
trial_fato['credenciamento_aprovado'] = trial_fato['credenciamento_aprovado'].astype('str')
trial_fato['conversao'] = trial_fato['conversao'].astype('str')

# %%
trial_fato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_clinica                   983 non-null    int64
#  1   id_canal                     983 non-null    int64
#  2   data_inicio_trial            983 non-null    datetime64[ns]
#  3   data_fim_trial               983 non-null    datetime64[ns]
#  4   num_dias_trial               983 non-null    int64
#  5   intervalo_duracao_trial      983 non-null    object
#  6   total_atividades_realizadas  983 non-null    Int64
#  7   intervalo_nro_atividades     983 non-null    object
#  8   solicitou_credenciamento     983 non-null    object
#  9   credenciamento_aprovado      983 non-null    object
#  10  credenciamento_status        983 non-null    object
#  11  conversao                    983 non-null    object
#  12  data_assinatura              270 non-null    datetime64[ns]
#  13  status_assinatura            270 non-null    object
#  14  num_dias_para_assinatura     270 non-null    Int64
# dtypes: Int64(2), datetime64[ns](3), int64(3), object(7)
# memory usage: 117.2+ KB

# %%
# Alterar os valores True -> Sim, False -> Não.
trial_fato['solicitou_credenciamento'] = np.where(trial_fato['solicitou_credenciamento'] == 'True', 'Sim', 'Não')
trial_fato['credenciamento_aprovado'] = np.where(trial_fato['credenciamento_aprovado'] == 'True', 'Sim', 'Não')
trial_fato['conversao'] = np.where(trial_fato['conversao'] == 'True', 'Sim', 'Não')
trial_fato
# Out:
#      id_clinica  id_canal data_inicio_trial data_fim_trial  num_dias_trial  \
# 0          9825         0        2023-08-21     2023-08-25               4
# 1          9984         1        2023-08-24     2023-08-31               7
# 2          9986         1        2023-08-24     2023-09-14              21
# 3          9988         1        2023-08-24     2023-08-31               7
# 4          9690         2        2023-08-17     2023-08-24               7
# ..          ...       ...               ...            ...             ...
# 978        9011         0        2023-08-01     2023-10-11              71
# 979       11180         0        2023-09-27     2023-10-10              13
# 980       11146         2        2023-09-26     2023-10-17              21
# 981       10314         0        2023-09-05     2023-10-17              42
# 982       11031         0        2023-09-23     2023-10-18              25
#
#     intervalo_duracao_trial  total_atividades_realizadas  \
# 0                Até 7 dias                          173
# 1                Até 7 dias                           14
# 2          Acima de 14 dias                            4
# 3                Até 7 dias                            1
# 4                Até 7 dias                            1
# ..                      ...                          ...
# 978        Acima de 14 dias                            0
# 979       Entre 8 e 14 dias                            0
# 980        Acima de 14 dias                            0
# 981        Acima de 14 dias                            1
# 982        Acima de 14 dias                            7
#
#      intervalo_nro_atividades solicitou_credenciamento  \
# 0      Acima de 50 atividades                      Sim
# 1    Entre 11 e 20 atividades                      Sim
# 2           Até 10 atividades                      Sim
# 3           Até 10 atividades                      Não
# 4           Até 10 atividades                      Não
# ..                        ...                      ...
# 978   Não realizou atividades                      Sim
# 979   Não realizou atividades                      Sim
# 980   Não realizou atividades                      Sim
# 981         Até 10 atividades                      Sim
# 982         Até 10 atividades                      Sim
#
#     credenciamento_aprovado credenciamento_status conversao data_assinatura  \
# 0                       Sim             Concluído       Sim      2023-08-25
# 1                       Sim             Concluído       Não             NaT
# 2                       Sim             Concluído       Não             NaT
# 3                       Não   Não aderiu ao plano       Não             NaT
# 4                       Não   Não aderiu ao plano       Não             NaT
# ..                      ...                   ...       ...             ...
# 978                     Sim             Concluído       Não             NaT
# 979                     Sim             Concluído       Sim      2023-10-10
# 980                     Sim             Concluído       Não             NaT
# 981                     Sim             Concluído       Sim      2023-10-17
# 982                     Não             Reprovado       Sim      2023-10-18
#
#     status_assinatura  num_dias_para_assinatura
# 0              active                         4
# 1                 NaN                      <NA>
# 2                 NaN                      <NA>
# 3                 NaN                      <NA>
# 4                 NaN                      <NA>
# ..                ...                       ...
# 978               NaN                      <NA>
# 979            active                        13
# 980               NaN                      <NA>
# 981            active                        42
# 982          canceled                        25
#
# [983 rows x 15 columns]

# %% [markdown]
# * #### Postgres

# %%
# Carrega as variaveis de ambiente.
load_dotenv(encoding="utf-8", override=True)
# Out:
# True

# %%
# Parametros para conexão no PostgreSQL
url = {"username" : os.getenv("USUARIO"), "password" : os.getenv("PWD"), "host" : "localhost", "port" : 5433, "database" : os.getenv("DB")}

# %%
# função para lidar e  analisar psycopg2 exceptions
def show_psycopg2_exception(err):
    # coleta detalhes sore a exception
    err_type, err_obj, traceback = sys.exc_info()    
    # pega a linha quando a exception ocorrer
    line_n = traceback.tb_lineno    
    # print the connect() error
    print ("\npsycopg2 ERROR:", err, "on line number:", line_n)
    print ("psycopg2 traceback:", traceback, "-- type:", err_type) 
    # psycopg2 extensions.Diagnostics object attribute
    print ("\nextensions.Diagnostics:", err.diag)    
    # print the pgcode and pgerror exceptions
    print ("pgerror:", err.pgerror)
    print ("pgcode:", err.pgcode, "\n")

# %%
def conn_pg(url):
    try:
        print('Conectando-se ao PostgreSQL...........')
        conn_pg = URL.create("postgresql+psycopg2", **url)
        engine_pg = create_engine(conn_pg)
        print("Conexão bem-sucedida..................")
    except OperationalError as err:
        # passando exception para função
        show_psycopg2_exception(err)        
        # setando conn_pg  = 'None' em caso de erro
        conn_pg = None
    return engine_pg

# %%
engine_pg = conn_pg(url)
# Out:
# Conectando-se ao PostgreSQL...........
# Conexão bem-sucedida..................

# %%
engine_pg
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/aquisicao_clinicas_star_schema)

# %%
def select_pg(engine, table):
    try:
        with engine.begin() as conn:
            df = pd.read_sql_query(f'select * from {table}', conn)
            return df
    except OperationalError as err:
        df = None
        # passando exception para função
        show_psycopg2_exception(err)

# %%
select_pg(engine_pg, 'trial_fato')
# Out:
# Empty DataFrame
# Columns: [id_trial, id_clinica, id_canal, data_inicio_trial, data_fim_trial, num_dias_trial, intervalo_duracao_trial, total_atividades_realizadas, intervalo_nro_atividades, solicitou_credenciamento, credenciamento_aprovado, credenciamento_status, conversao, data_assinatura, status_assinatura, num_dias_para_assinatura]
# Index: []

# %%
def insert_pg(engine, df, table):
    try:
        with engine.begin() as conn:
            df.to_sql(f'{table}', con=engine, index=False, if_exists='append',chunksize = 1000)
            print(f"Dados inseridos na tabela {table} com sucesso...")
    except (OperationalError, IntegrityError) as err:
        # passando exception para função
        show_psycopg2_exception(err)

# %%
funcionalidade_dim
# Out:
#     id_funcionalidade   nom_funcionalidade
# 0                   0   patient_management
# 1                   1           scheduling
# 2                   2       medical_record
# 3                   3             anamnese
# 4                   4      user_management
# 5                   5    budget_management
# 6                   6         credit_check
# 7                   7                 bnpl
# 8                   8  documents_and_files
# 9                   9   revenue_management
# 10                 10         payment_book

# %%
insert_pg(engine_pg, funcionalidade_dim, 'funcionalidade_dim')
# Out:
# Dados inseridos na tabela funcionalidade_dim com sucesso...

# %%
select_pg(engine_pg, 'funcionalidade_dim')
# Out:
#     id_funcionalidade   nom_funcionalidade
# 0                   0   patient_management
# 1                   1           scheduling
# 2                   2       medical_record
# 3                   3             anamnese
# 4                   4      user_management
# 5                   5    budget_management
# 6                   6         credit_check
# 7                   7                 bnpl
# 8                   8  documents_and_files
# 9                   9   revenue_management
# 10                 10         payment_book

# %%
canal_marketing_dim
# Out:
#   MARKETING_ATTRIBUITION_CHANNEL_GROUP  \
# 0                          Paid - meta
# 1                        Paid - google
# 2                                Other
# 3            Site ou Indicação Interna
# 4                              Organic
#
#    ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP
# 0                                        0
# 1                                        1
# 2                                        2
# 3                                        3
# 4                                        4

# %%
# Ajustes para exportar para a tabela no Postgres.
# Renomeando colunas
canal_marketing_dim.rename(columns={'MARKETING_ATTRIBUITION_CHANNEL_GROUP':'nom_canal', 'ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP':'id_canal'}, inplace=True)
canal_marketing_dim
# Out:
#                    nom_canal  id_canal
# 0                Paid - meta         0
# 1              Paid - google         1
# 2                      Other         2
# 3  Site ou Indicação Interna         3
# 4                    Organic         4

# %%
insert_pg(engine_pg, canal_marketing_dim, 'canal_marketing_dim')
# Out:
# Dados inseridos na tabela canal_marketing_dim com sucesso...

# %%
select_pg(engine_pg, 'canal_marketing_dim')
# Out:
#    id_canal                  nom_canal
# 0         0                Paid - meta
# 1         1              Paid - google
# 2         2                      Other
# 3         3  Site ou Indicação Interna
# 4         4                    Organic

# %%
clinica_dim
# Out:
#        id_clinica           data_cadastro
# 0            9825 2023-08-21 09:14:34.763
# 1            9984 2023-08-24 19:40:58.432
# 5            9986 2023-08-24 20:31:43.062
# 7            9988 2023-08-24 22:04:10.022
# 9            9690 2023-08-17 04:33:00.786
# ...           ...                     ...
# 12393        9011 2023-08-01 13:01:05.019
# 12395       11180 2023-09-27 14:01:04.040
# 12397       11146 2023-09-26 19:21:15.702
# 12399       10314 2023-09-05 01:05:51.799
# 12401       11031 2023-09-23 20:03:38.288
#
# [983 rows x 2 columns]

# %%
insert_pg(engine_pg, clinica_dim, 'clinica_dim')
# Out:
# Dados inseridos na tabela clinica_dim com sucesso...

# %%
select_pg(engine_pg, 'clinica_dim')
# Out:
#      id_clinica           data_cadastro
# 0          9825 2023-08-21 09:14:34.763
# 1          9984 2023-08-24 19:40:58.432
# 2          9986 2023-08-24 20:31:43.062
# 3          9988 2023-08-24 22:04:10.022
# 4          9690 2023-08-17 04:33:00.786
# ..          ...                     ...
# 978        9011 2023-08-01 13:01:05.019
# 979       11180 2023-09-27 14:01:04.040
# 980       11146 2023-09-26 19:21:15.702
# 981       10314 2023-09-05 01:05:51.799
# 982       11031 2023-09-23 20:03:38.288
#
# [983 rows x 2 columns]

# %%
funcionalidade_utilizada_fato
# Out:
#       id_clinica  id_funcionalidade  num_qtde_vezes
# 0           8994                  5               1
# 1           8994                  2               2
# 2           8994                  9               1
# 3           8994                  1               1
# 4           8998                  3               2
# ...          ...                ...             ...
# 2294       11295                  0               2
# 2295       11295                  1               1
# 2296       11296                  1               1
# 2297       11301                  1               1
# 2298       11302                  1               1
#
# [2299 rows x 3 columns]

# %%
insert_pg(engine_pg, funcionalidade_utilizada_fato, 'funcionalidade_utilizada_fato')
# Out:
# Dados inseridos na tabela funcionalidade_utilizada_fato com sucesso...

# %%
select_pg(engine_pg, 'funcionalidade_utilizada_fato')
# Out:
#       id_funcionalidade_utilizada  id_clinica  id_funcionalidade  \
# 0                               1        8994                  5
# 1                               2        8994                  2
# 2                               3        8994                  9
# 3                               4        8994                  1
# 4                               5        8998                  3
# ...                           ...         ...                ...
# 2294                         2295       11295                  0
# 2295                         2296       11295                  1
# 2296                         2297       11296                  1
# 2297                         2298       11301                  1
# 2298                         2299       11302                  1
#
#       num_qtde_vezes
# 0                  1
# 1                  2
# 2                  1
# 3                  1
# 4                  2
# ...              ...
# 2294               2
# 2295               1
# 2296               1
# 2297               1
# 2298               1
#
# [2299 rows x 4 columns]

# %%
trial_fato
# Out:
#      id_clinica  id_canal data_inicio_trial data_fim_trial  num_dias_trial  \
# 0          9825         0        2023-08-21     2023-08-25               4
# 1          9984         1        2023-08-24     2023-08-31               7
# 2          9986         1        2023-08-24     2023-09-14              21
# 3          9988         1        2023-08-24     2023-08-31               7
# 4          9690         2        2023-08-17     2023-08-24               7
# ..          ...       ...               ...            ...             ...
# 978        9011         0        2023-08-01     2023-10-11              71
# 979       11180         0        2023-09-27     2023-10-10              13
# 980       11146         2        2023-09-26     2023-10-17              21
# 981       10314         0        2023-09-05     2023-10-17              42
# 982       11031         0        2023-09-23     2023-10-18              25
#
#     intervalo_duracao_trial  total_atividades_realizadas  \
# 0                Até 7 dias                          173
# 1                Até 7 dias                           14
# 2          Acima de 14 dias                            4
# 3                Até 7 dias                            1
# 4                Até 7 dias                            1
# ..                      ...                          ...
# 978        Acima de 14 dias                            0
# 979       Entre 8 e 14 dias                            0
# 980        Acima de 14 dias                            0
# 981        Acima de 14 dias                            1
# 982        Acima de 14 dias                            7
#
#      intervalo_nro_atividades solicitou_credenciamento  \
# 0      Acima de 50 atividades                      Sim
# 1    Entre 11 e 20 atividades                      Sim
# 2           Até 10 atividades                      Sim
# 3           Até 10 atividades                      Não
# 4           Até 10 atividades                      Não
# ..                        ...                      ...
# 978   Não realizou atividades                      Sim
# 979   Não realizou atividades                      Sim
# 980   Não realizou atividades                      Sim
# 981         Até 10 atividades                      Sim
# 982         Até 10 atividades                      Sim
#
#     credenciamento_aprovado credenciamento_status conversao data_assinatura  \
# 0                       Sim             Concluído       Sim      2023-08-25
# 1                       Sim             Concluído       Não             NaT
# 2                       Sim             Concluído       Não             NaT
# 3                       Não   Não aderiu ao plano       Não             NaT
# 4                       Não   Não aderiu ao plano       Não             NaT
# ..                      ...                   ...       ...             ...
# 978                     Sim             Concluído       Não             NaT
# 979                     Sim             Concluído       Sim      2023-10-10
# 980                     Sim             Concluído       Não             NaT
# 981                     Sim             Concluído       Sim      2023-10-17
# 982                     Não             Reprovado       Sim      2023-10-18
#
#     status_assinatura  num_dias_para_assinatura
# 0              active                         4
# 1                 NaN                      <NA>
# 2                 NaN                      <NA>
# 3                 NaN                      <NA>
# 4                 NaN                      <NA>
# ..                ...                       ...
# 978               NaN                      <NA>
# 979            active                        13
# 980               NaN                      <NA>
# 981            active                        42
# 982          canceled                        25
#
# [983 rows x 15 columns]

# %%
insert_pg(engine_pg, trial_fato, 'trial_fato')
# Out:
# Dados inseridos na tabela trial_fato com sucesso...

# %%
select_pg(engine_pg, 'trial_fato')
# Out:
#      id_trial  id_clinica  id_canal data_inicio_trial data_fim_trial  \
# 0           1        9825         0        2023-08-21     2023-08-25
# 1           2        9984         1        2023-08-24     2023-08-31
# 2           3        9986         1        2023-08-24     2023-09-14
# 3           4        9988         1        2023-08-24     2023-08-31
# 4           5        9690         2        2023-08-17     2023-08-24
# ..        ...         ...       ...               ...            ...
# 978       979        9011         0        2023-08-01     2023-10-11
# 979       980       11180         0        2023-09-27     2023-10-10
# 980       981       11146         2        2023-09-26     2023-10-17
# 981       982       10314         0        2023-09-05     2023-10-17
# 982       983       11031         0        2023-09-23     2023-10-18
#
#      num_dias_trial intervalo_duracao_trial  total_atividades_realizadas  \
# 0                 4              Até 7 dias                          173
# 1                 7              Até 7 dias                           14
# 2                21        Acima de 14 dias                            4
# 3                 7              Até 7 dias                            1
# 4                 7              Até 7 dias                            1
# ..              ...                     ...                          ...
# 978              71        Acima de 14 dias                            0
# 979              13       Entre 8 e 14 dias                            0
# 980              21        Acima de 14 dias                            0
# 981              42        Acima de 14 dias                            1
# 982              25        Acima de 14 dias                            7
#
#      intervalo_nro_atividades solicitou_credenciamento  \
# 0      Acima de 50 atividades                      Sim
# 1    Entre 11 e 20 atividades                      Sim
# 2           Até 10 atividades                      Sim
# 3           Até 10 atividades                      Não
# 4           Até 10 atividades                      Não
# ..                        ...                      ...
# 978   Não realizou atividades                      Sim
# 979   Não realizou atividades                      Sim
# 980   Não realizou atividades                      Sim
# 981         Até 10 atividades                      Sim
# 982         Até 10 atividades                      Sim
#
#     credenciamento_aprovado credenciamento_status conversao data_assinatura  \
# 0                       Sim             Concluído       Sim      2023-08-25
# 1                       Sim             Concluído       Não            None
# 2                       Sim             Concluído       Não            None
# 3                       Não   Não aderiu ao plano       Não            None
# 4                       Não   Não aderiu ao plano       Não            None
# ..                      ...                   ...       ...             ...
# 978                     Sim             Concluído       Não            None
# 979                     Sim             Concluído       Sim      2023-10-10
# 980                     Sim             Concluído       Não            None
# 981                     Sim             Concluído       Sim      2023-10-17
# 982                     Não             Reprovado       Sim      2023-10-18
#
#     status_assinatura  num_dias_para_assinatura
# 0              active                       4.0
# 1                None                       NaN
# 2                None                       NaN
# 3                None                       NaN
# 4                None                       NaN
# ..                ...                       ...
# 978              None                       NaN
# 979            active                      13.0
# 980              None                       NaN
# 981            active                      42.0
# 982          canceled                      25.0
#
# [983 rows x 16 columns]

# %% [markdown]
# * #### Criando datasets para realizar os testes de hipoteses.

# %%
canal_marketing_dim.rename(columns={'MARKETING_ATTRIBUITION_CHANNEL_GROUP':'nom_canal', 'ID_MARKETING_ATTRIBUITION_CHANNEL_GROUP':'id_canal'}, inplace=True)
canal_marketing_dim
# Out:
#                    nom_canal  id_canal
# 0                Paid - meta         0
# 1              Paid - google         1
# 2                      Other         2
# 3  Site ou Indicação Interna         3
# 4                    Organic         4

# %%
df_trial_metricas = pd.merge(trial_fato, canal_marketing_dim, on='id_canal', how='left')
df_trial_metricas
# Out:
#      id_clinica  id_canal data_inicio_trial data_fim_trial  num_dias_trial  \
# 0          9825         0        2023-08-21     2023-08-25               4
# 1          9984         1        2023-08-24     2023-08-31               7
# 2          9986         1        2023-08-24     2023-09-14              21
# 3          9988         1        2023-08-24     2023-08-31               7
# 4          9690         2        2023-08-17     2023-08-24               7
# ..          ...       ...               ...            ...             ...
# 978        9011         0        2023-08-01     2023-10-11              71
# 979       11180         0        2023-09-27     2023-10-10              13
# 980       11146         2        2023-09-26     2023-10-17              21
# 981       10314         0        2023-09-05     2023-10-17              42
# 982       11031         0        2023-09-23     2023-10-18              25
#
#      total_atividades_realizadas  solicitou_credenciamento  \
# 0                            173                      True
# 1                             14                      True
# 2                              4                      True
# 3                              1                     False
# 4                              1                     False
# ..                           ...                       ...
# 978                            0                      True
# 979                            0                      True
# 980                            0                      True
# 981                            1                      True
# 982                            7                      True
#
#      credenciamento_aprovado credenciamento_status  realizou_assinatura  \
# 0                       True             Concluído                 True
# 1                       True             Concluído                False
# 2                       True             Concluído                False
# 3                      False   Não aderiu ao plano                False
# 4                      False   Não aderiu ao plano                False
# ..                       ...                   ...                  ...
# 978                     True             Concluído                False
# 979                     True             Concluído                 True
# 980                     True             Concluído                False
# 981                     True             Concluído                 True
# 982                    False             Reprovado                 True
#
#     data_assinatura status_assinatura  num_dias_para_assinatura      nom_canal
# 0        2023-08-25            active                         4    Paid - meta
# 1               NaT               NaN                      <NA>  Paid - google
# 2               NaT               NaN                      <NA>  Paid - google
# 3               NaT               NaN                      <NA>  Paid - google
# 4               NaT               NaN                      <NA>          Other
# ..              ...               ...                       ...            ...
# 978             NaT               NaN                      <NA>    Paid - meta
# 979      2023-10-10            active                        13    Paid - meta
# 980             NaT               NaN                      <NA>          Other
# 981      2023-10-17            active                        42    Paid - meta
# 982      2023-10-18          canceled                        25    Paid - meta
#
# [983 rows x 14 columns]

# %%
df_funcionalidade_metricas = pd.merge(funcionalidade_utilizada_fato, funcionalidade_dim, on='id_funcionalidade', how='left')
df_funcionalidade_metricas
# Out:
#       id_clinica  id_funcionalidade  num_qtde_vezes  nom_funcionalidade
# 0           8994                  5               1   budget_management
# 1           8994                  2               2      medical_record
# 2           8994                  9               1  revenue_management
# 3           8994                  1               1          scheduling
# 4           8998                  3               2            anamnese
# ...          ...                ...             ...                 ...
# 2294       11295                  0               2  patient_management
# 2295       11295                  1               1          scheduling
# 2296       11296                  1               1          scheduling
# 2297       11301                  1               1          scheduling
# 2298       11302                  1               1          scheduling
#
# [2299 rows x 4 columns]

# %%
# Exportando os datasets
df_trial_metricas.to_csv(r'..\dados\df_trial_metricas.csv', index=False)
df_funcionalidade_metricas.to_csv(r'..\dados\df_funcionalidade_metricas.csv', index=False)
